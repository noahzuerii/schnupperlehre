# %% [markdown]
# ## `1. Hello World!`
# Schreibe ein Programm, das den Text `Hello World!` in der Kommandozeile ausgibt.
# ### Tips:
# * Um etwas auszugeben kann man die Funktion `print(x)` verwenden
# * Um ein Stück Text in Python darzustellen, muss man ihn zwischen zwei Gänsefüsschen setzen `"text"`
# * https://www.pythoncheatsheet.org/builtin/print

# %%
# Drucke den text "Hello World!" aus:

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
import io, contextlib
_check_buf = io.StringIO()
with contextlib.redirect_stdout(_check_buf):
    exec(_ih[-2])
_check_output = _check_buf.getvalue()
assert "Hello World!" in _check_output, "Erwarte 'Hello World!' in der Ausgabe. Deine Ausgabe war: " + repr(_check_output)
print("Richtig!")

# %% [markdown]
# Im unteren Code sind bereits die Variablen `name` und `alter` vorhanden, drucke diese aus.

# %%
# Vordefinierte Variablen:
name = "John"
alter = 17

# Code der die Variablen "name" und "alter" ausdruckt:

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
import io, contextlib
_check_buf = io.StringIO()
with contextlib.redirect_stdout(_check_buf):
    exec(_ih[-2])
_check_output = _check_buf.getvalue()
assert "John" in _check_output, "Der Name (John) sollte ausgedruckt werden."
assert "17" in _check_output, "Das Alter (17) sollte ausgedruckt werden."
print("Richtig!")

# %% [markdown]
# ## `2. Bedingungen`
# Schreibe ein Programm, das die Variable `alter` auswertet und entweder:
# * "`Die Person ist minderjährig`" druckt, wenn das Alter weniger als 18 ist. (`alter < 18`)
# * "`Die Person ist 18 Jahre alt`" druckt, wenn das Alter genau 18 Jahre ist. (`alter == 18`)
# * "`Die Person ist über 18`" druckt, wenn das Alter grösser als 18 ist (`alter > 18`)
#
# ### Tips:
# * https://www.pythoncheatsheet.org/cheatsheet/control-flow

# %%
# Vordefinierte Variablen:
alter = 16

# Code der das Alter auswertet:

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
import io, contextlib
_check_buf = io.StringIO()
with contextlib.redirect_stdout(_check_buf):
    exec(_ih[-2])
_check_output = _check_buf.getvalue()
assert "Die Person ist minderjährig" in _check_output, "Bei alter=16 sollte 'Die Person ist minderjährig' ausgegeben werden. Deine Ausgabe: " + repr(_check_output)
print("Richtig!")

# %% [markdown]
# ## `3. Schleifen`
# Schreibe ein Programm, das die korrekte Zahl errät. Verwende eine while-Schleife, um deine Schätzung anzupassen, bis die "`korrekte_zahl`" gefunden wird. Beginne bei 1 und erhöhe deine `schätzung` jeweils um 1, bis sie der `korrekten_zahl` entspricht.
# ### Tips:
# * https://www.pythoncheatsheet.org/cheatsheet/control-flow#while-loop-statements

# %%
# Zahl die erraten werden muss
korrekte_zahl = 78

# Code welcher so lange die Schätzung anpasst, bis er die korrekte Zahl findet:
schätzung = 0

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
assert schätzung == korrekte_zahl, f"schätzung ist {schätzung}, sollte aber {korrekte_zahl} sein."
print("Richtig!")

# %% [markdown]
# ## `4. Iteration`
# Schreibe ein Programm, das eine **for** Schleife verwendet, um jedes Element einer Liste von Namen auszugeben.
# ### Tips:
# * https://www.pythoncheatsheet.org/cheatsheet/control-flow#for-loop

# %%
# Vordefinierte Variablen:
namen = ["Anna", "Ben", "Clara", "David", "Eva"]

# Code welcher alle Namen nacheinander ausdruckt:

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
import io, contextlib
_check_buf = io.StringIO()
with contextlib.redirect_stdout(_check_buf):
    exec(_ih[-2])
_check_output = _check_buf.getvalue()
_missing = [n for n in namen if n not in _check_output]
assert not _missing, "Diese Namen fehlen in der Ausgabe: " + ", ".join(_missing)
print("Richtig!")

# %% [markdown]
# ## `5. Funktion`
# Schreibe eine eigene Funktion, (die ähnlich wie Aufgabe 3) das Alter eines Benutzers auswertet. Die Funktion nimmt eine Zahl als Input und gibt einen String zurück.
# ### Tips:
# * https://www.pythoncheatsheet.org/cheatsheet/functions
# * https://www.pythoncheatsheet.org/cheatsheet/functions#return-values

# %%
# Funktion:


# Code der die Funktion ausführt:
print(ist_volljährig(27))

# %%
# Prüfen (optional): führe diese Zelle aus, um deine Lösung zu testen.
_r1, _r2, _r3 = ist_volljährig(16), ist_volljährig(18), ist_volljährig(21)
assert isinstance(_r1, str) and isinstance(_r2, str) and isinstance(_r3, str), "Die Funktion soll einen Text zurückgeben (return), nicht nur ausdrucken (print)."
assert _r1 != _r2 and _r2 != _r3 and _r1 != _r3, "Die Funktion soll für minderjährig / 18 Jahre / über 18 unterschiedliche Texte zurückgeben."
print("Richtig!")
