# %% [markdown]
# ## `Frei`
# Diese Aufgabe ist offen: Es gibt keine feste Beschreibung. Probiere etwas aus, das dich interessiert, z.B. eines der Themen aus [Erweitert](./02_Erweitert.ipynb) oder [Advanced](./03_Advanced.ipynb) weiterspinnen, ein eigenes kleines Programm schreiben, oder einfach mit Python herumspielen.
